# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px; ">
# <b> Комментарий ревьюера</b>
#
# Привет! Меня зовут Светлана Носова, я буду проверять твой проект. Если не против, давай общаться на «ты». Если тебе такой стиль общения не нравится, напиши об этом, будем на «вы».
#
# Сразу хочу обратить внимание на цветовую разметку:
#
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Зеленым с пометкой ✔️ отмечены отличные решения и идеи, которые можно и нужно использовать в будущем.
# </div>
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Желтым с пометкой ⚠️ отмечено то, что можно или нужно оптимизировать, в зависимости от контекста.</div>
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Красным с пометкой ❌ обозначены пропущенные пункты задания и ошибки, которые обязательно надо будет исправить, чтобы результаты были верные.</div>
#
# **Ответы на мои комментарии или доработки по моим рекомендациям попрошу выделить каким-нибудь цветом, кроме трех перечисленных.**
# Также я попрошу тебя **не менять и не передвигать мои комментарии**, чтобы при последующей проверке мне было проще ориентироваться.
#
# Кроме того, комментарии у меня обозначены как заголовки. Это сбивает содержание, но при последующей проверке я могу снять с них заголовок, если тебе так будет удобнее. При этом они удобны, поскольку ты сразу можешь перейти к ним.
#
# <hr>
#
# <font color= 'dodgerblue'>**По проекту:**</font> работа сделана очень качественно, все оформлено аккуратно и понятно. Структура работы у тебя грамотная, код легко читается, много анализа и выводов. У меня всего парочка вопросов, я все обозначила в комментариях. Там же я оставила рекомендации по улучшению проекта. Буду ждать работу на повторное ревью.
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Комментарий ревьюера 2</b>
#
# Спасибо за корректировки. Я оставила новые комментарии с цифрой 2, а со старых сняла заголовки, чтобы  не мешали. Проект я могу принять, поскольку вопросов больше нет. Желаю успехов в дальнейшем обучении :)
#
#
#
# </div>

# %% [markdown]
# # Сборный проект №1
# # Выявление определяющих успешность игры закономерностей

# %% [markdown]
# В нашем распоряжении исторические данные до 2016 года из открытых источников о продажах игр, оценки пользователей и экспертов, жанры и платформы. Необходимо выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Хорошо, что добавляешь краткое описание задачи. Это поможет быстро вспомнить, о чем проект, когда ты вернешься к нему.    Кроме того, так работа выглядит гораздо презентабельнее.
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера  ⚠️</h2>
#
# В будущем рекомендую делать его чуть шире и добавлять содержание. Так в работе будет проще ориентироваться.
# </div>

# %% [markdown]
# ## Открытие файла с данными и изучение информации

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats as st
import warnings
warnings.filterwarnings('ignore')

# %%
try:
    df=pd.read_csv('/datasets/games.csv')
except:
    df=pd.read_cxv('https://code.s3.yandex.net/datasets/games.csv')
df.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#    NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     41.36     28.96      3.77         8.45          76.0          8      E
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️ </h2>
#
# Классно, что используешь `try-except`. Хотя эта конструкция предназначена для отлавливания конкретных ошибок, тут она вполне пригодна. Иногда полезны `else` и `finally`. Так, `try` блок позволяет нам что-то попытаться сделать. `except` ловит исключения и ошибки. `else` делает что-то, если ошибок не было. `finally` выполняется всегда, даже если была ошибка. `finally` может быть полезен, когда тебе точно надо что-то сделать. Например, закрыть файл. Глянь на кусок кода ниже:
#
#
# </div>
#
# ```python
#
# try:
#     # Что-то делаем.
# except Exception as e:
#     # Обрабатываем исключение.
#     # То есть мы ожидаем, что может случиться ошибка.
# else:
#     # Выполянем что-то, если нет ошибок.
# finally:
#     # Выполянем что-то при любом раскладе.
#
# ```

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         Other_sales  Critic_Score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %% [markdown]
# Данные содержат 11 колонок и 16715 строк, есть пропуски.
#
#     `Name` — название игры
#     `Platform` — платформа
#     `Year_of_Release` — год выпуска
#     `Genre` — жанр игры
#     `NA_sales` — продажи в Северной Америке (миллионы проданных копий)
#     `EU_sales` — продажи в Европе (миллионы проданных копий)
#     `JP_sales` — продажи в Японии (миллионы проданных копий)
#     `Other_sales` — продажи в других странах (миллионы проданных копий)
#     `Critic_Score` — оценка критиков (максимум 100)
#     `User_Score` — оценка пользователей (максимум 10)
#     `Rating` — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Явные дубликаты

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явных дубликатов не выявлено

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️ </h2>
#
# Важная проверка. Здорово, что помнишь про нее, потому что иногда дубликаты могут испортить весь анализ.
#
# </div>

# %% [markdown]
# ### Название столбцов

# %%
df.columns=df.columns.str.lower()

# %% [markdown]
# Привели название колонок к нижнему регистру

# %% [markdown]
# ### Работа с пропусками

# %%
df.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %%
df[df['name'].isna()==True]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN

# %% [markdown]
# Удалим 2 строки с пропусками в колонке `name`

# %%
df = df.dropna(subset=['name'])
df['name'].isna().sum()
# Out:
# 0

# %% [markdown]
# Удалим строки с пропущенным годом релиза, так как их немного, всего 269 строк

# %%
df = df.dropna(subset=['year_of_release'])
df.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8461
# user_score         6605
# rating             6676
# dtype: int64

# %% [markdown]
# Пропуски в столбцах `critic_score`, `user_score` и `raiting` заменять или удалять не будем, так как пропусков достаточно много. Появились они скорее всего в следствии того, что игры настолько непримечательные, что не заслужили участия в рейтингах.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️ </h2>
#
# Согласна с решением.
# </div>

# %% [markdown]
# ### Изменение типов данных

# %% [markdown]
# Изменим тип данных в столбце `year_of_release` на цельночисленный

# %%
df['year_of_release'] = df['year_of_release'].astype('int')

# %% [markdown]
# Поработаем со столбцом `user_score`

# %%
df['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %% [markdown]
# В столбце имеется значение tbd, что означает To Be Determined или To Be Discussed, что, в свою очередь, означает будет определено либо будет обсуждено, то есть пока что рейтинга нет, поставим nan. Изменим тип на числовой с плавающей точкой.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Да, это допустимо.
#
# </div>

# %%
df.loc[df['user_score']=='tbd', 'user_score'] = float('nan')
df['user_score'] = df['user_score'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16444 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16444 non-null  object
#  2   year_of_release  16444 non-null  int64
#  3   genre            16444 non-null  object
#  4   na_sales         16444 non-null  float64
#  5   eu_sales         16444 non-null  float64
#  6   jp_sales         16444 non-null  float64
#  7   other_sales      16444 non-null  float64
#  8   critic_score     7983 non-null   float64
#  9   user_score       7463 non-null   float64
#  10  rating           9768 non-null   object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# Поработаем с рейтингами

# %%
df['rating'].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %% [markdown]
# Рейтинги 'E' и 'K-A' - это один и тотже рейтинг, заменим все 'K-A' на 'E'

# %%
df['rating'] = df['rating'].replace('K-A', 'E')
df['rating'].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'AO', 'EC', 'RP'], dtype=object)

# %% [markdown]
# ### Суммарные продажи во всех регионах

# %% [markdown]
# Добавим столбец `total_sales` с подсчетом всех продаж по всем регионам

# %%
df['total_sales'] = df['na_sales'] + df['eu_sales'] + df['jp_sales'] + df['other_sales']

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Можно еще взять метод **sum** с аргументом **axis=1**.
#
# </div>
#
# ```python
#
#
# df['total_sales'] = df[['na_sales','eu_sales','jp_sales','other_sales']].sum(axis=1)
# ```

# %% [markdown]
# <p><strong>Вывод</strong></p>
# <p>При подготовке данных явные дубликаты выявлены не были, неявные дубликаты в столбце с рейтингами были устранены (раннее обозначение рейтинга 'K-A' было заменено на 'E').</p>
# <p>Названия столбцов были приведены к нижнему регистру.</p>
# <p>Обработаны пропуски в данных:</p>
# <ul>
# <li>удалены пропуски в столбцах name, genre и year_of_release, так как пропусков было немного (менее 2% процентов от всего датасета)</li>
# <li>пропуски в столбцах critic_score, user_score и rating были оставлены как есть</li>
# </ul>
# <p>Так как данные были взяты из открытых источников, скорее всего спарсены с интернет-страниц нужной тематики, то пропусков оказалось довольно много по причине кривости парсинга, либо недостатка данных в представленных источниках.</p>
# <p>Был изменен тип данных в столбце year_of_release на цельночисленный для удобства читаемости и дальнейшей работы, столбец user_score приведен к типу float, значение tbd, что означает To Be Determined или To Be Discussed, что, в свою очередь, означает будет определено либо будет обсуждено, то есть пока что рейтинга нет, заменен на nan.</p>
# <p>Был добавлен столбец total_sales с подсчетом всех продаж по всем регионам.</p>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Отличная работа в этом разделе.
# </div>

# %% [markdown]
# ## Исследовательский анализ

# %% [markdown]
# ### Количество игр в год

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера  ⚠️</b>
#
# Загрузку лучше делать в начале проекта, тогда читателю будет сразу понятно, какие модули потребуются для запуска проекта.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Отлично 👍
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>Комментарий студента V1<a class="tocSkip"></h2>
# <div>Убрала загрузку библиотек в начало.</div>

# %%
(df.groupby('year_of_release')['name'].count()).plot(title = 'Релизы', figsize=(15, 8), xlabel='Год выпуска', ylabel = 'Количество релизов')
# Out:
# <AxesSubplot:title={'center':'Релизы'}, xlabel='Год выпуска', ylabel='Количество релизов'>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Отличная визуализация. Уже по ней можно прикинуть актуальный период.
#
#
# Чтобы избавиться от строки над графиком, ставь или точку с запятой в конце кода, или используй `plt.show`. </div>

# %%
df.groupby('year_of_release')['name'].count().sort_values(ascending=False)
# Out:
# year_of_release
# 2008    1427
# 2009    1426
# 2010    1255
# 2007    1197
# 2011    1136
# 2006    1006
# 2005     939
# 2002     829
# 2003     775
# 2004     762
# 2012     653
# 2015     606
# 2014     581
# 2013     544
# 2016     502
# 2001     482
# 1998     379
# 2000     350
# 1999     338
# 1997     289
# 1996     263
# 1995     219
# 1994     121
# 1993      60
# 1981      46
# 1992      43
# 1991      41
# 1982      36
# 1986      21
# 1989      17
# 1983      17
# 1990      16
# 1987      16
# 1988      15
# 1985      14
# 1984      14
# 1980       9
# Name: name, dtype: int64

# %% [markdown]
# Начиная с 1994 года количество релизов в год резко увеличивается, производство игр набирает обороты, но начиная с 2011 года заметен резкий спад. Самое большое количество игр было выпущено в 2008 и 2009 годах.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Верно. </div>

# %% [markdown]
# ### Продажи по платформам

# %%
platform_type = df.pivot_table(index=['platform'], values='total_sales', aggfunc='sum').sort_values('total_sales',ascending=False)
platform_type
# Out:
#           total_sales
# platform
# PS2           1233.56
# X360           961.24
# PS3            931.34
# Wii            891.18
# DS             802.78
# PS             727.58
# PS4            314.14
# GBA            312.88
# PSP            289.53
# 3DS            257.81
# PC             255.76
# GB             254.43
# XB             251.57
# NES            251.05
# N64            218.01
# SNES           200.04
# GC             196.73
# XOne           159.32
# 2600            86.48
# WiiU            82.19
# PSV             53.81
# SAT             33.59
# GEN             28.35
# DC              15.95
# SCD              1.86
# NG               1.44
# WS               1.42
# TG16             0.16
# 3DO              0.10
# GG               0.04
# PCFX             0.03

# %% [markdown]
# Наиболее продаваемые платформы:
#
#     PS2	- 1233.56
#     X360 - 961.24
#     PS3	- 931.34
#     Wii	- 891.18
#     DS	- 802.78
#     PS	- 727.58

# %%
top_p = platform_type[:6].reset_index()
tp=top_p['platform'].to_list()
tp
# Out:
# ['PS2', 'X360', 'PS3', 'Wii', 'DS', 'PS']

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Можно в одну строку это сделать. </div>

# %%
for i in tp:
    print('__________________', i, '________________')
    top_pl_sales = pd.pivot_table(df.query('platform == @i'), index=['year_of_release'], values='total_sales', aggfunc='sum')
    print(top_pl_sales)
    print('------------------------------------------')
    print()
# Out:
# __________________ PS2 ________________
#                  total_sales
# year_of_release
# 2000                   39.17
# 2001                  166.43
# 2002                  205.38
# 2003                  184.31
# 2004                  211.81
# 2005                  160.66
# 2006                  103.42
# 2007                   75.99
# 2008                   53.90
# 2009                   26.40
# 2010                    5.64
# 2011                    0.45
# ------------------------------------------
#
# __________________ X360 ________________
#                  total_sales
# year_of_release
# 2005                    8.25
# 2006                   51.62
# 2007                   95.41
# 2008                  135.26
# 2009                  120.29
# 2010                  170.03
# 2011                  143.84
# 2012                   99.74
# 2013                   88.58
# 2014                   34.74
# 2015                   11.96
# 2016                    1.52
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Напомню, что со строками можно проводить математические операции. Например: </div>

# %%
# КОД РЕВЬЮЕРА

print('-'*40)
# Out:
# ----------------------------------------

# %%
df.loc[(df['year_of_release']==1985) & (df['platform']=='DS')]
# Out:
#                                       name platform  year_of_release   genre  \
# 15957  Strongest Tokyo University Shogi DS       DS             1985  Action
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 15957       0.0       0.0      0.02          0.0           NaN         NaN
#
#       rating  total_sales
# 15957    NaN         0.02

# %% [markdown]
# Для платформы DS есть 1 строчка с датой релиза 1985 - этого не может быть, тк релиз самой платформы был в 2004 году, удалим эту строку из таблицы

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Очень хорошее наблюдение.
#
#
# Вместо констант лучше использовать переменные.
#
#
# Индекс можно получить программно: `df.loc[(df['year_of_release']==1985) & (df['platform']=='DS')].index`. Тогда при изменении таблицы и индексов код всегда будет работать одинаково. </div>

# %%
df = df.drop(index = 15957)

# %%
df.shape
# Out:
# (16443, 12)

# %%
for i in tp:
    pd.pivot_table(df.query('platform == @i'), index=['year_of_release'], values='total_sales', aggfunc='sum').plot(title = i, figsize=(10, 5), xlabel='Год выпуска', ylabel = 'Количество релизов').legend_ = None

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера  ⚠️</b>
#
# Легенду можно убрать.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Супер. Она не нужна, ведь у нас есть заголовок.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>Комментарий студента V1<a class="tocSkip"></h2>
# <div>Убрала легенду.</div>

# %% [markdown]
# Создадим сводную таблицу для подсчета периода существования платформы (добавим 1, тк период жизни будем считать с 1 января по 31 декабря)

# %%
lifetime = df.pivot_table(index='platform', values='year_of_release', aggfunc=['min', 'max']).reset_index()
lifetime.set_axis(['platform', 'first_year', 'last_year'], axis='columns', inplace=True)
lifetime['len'] = lifetime['last_year'] - lifetime['first_year'] + 1
lifetime = lifetime.sort_values(by='last_year', ascending=False)
lifetime
# Out:
#    platform  first_year  last_year  len
# 30     XOne        2013       2016    4
# 2       3DS        2011       2016    6
# 28     X360        2005       2016   12
# 27     WiiU        2012       2016    5
# 26      Wii        2006       2016   11
# 20      PSV        2011       2016    6
# 13       PC        1985       2016   32
# 18      PS4        2013       2016    4
# 17      PS3        2006       2016   11
# 19      PSP        2004       2015   12
# 4        DS        2004       2013   10
# 16      PS2        2000       2011   12
# 3        DC        1998       2008   11
# 29       XB        2000       2008    9
# 6       GBA        2000       2007    8
# 7        GC        2001       2007    7
# 15       PS        1994       2003   10
# 10      N64        1996       2002    7
# 25       WS        1999       2001    3
# 5        GB        1988       2001   14
# 21      SAT        1994       1999    6
# 23     SNES        1990       1999   10
# ...

# %%
lifetime.describe()
# Out:
#         first_year    last_year        len
# count    31.000000    31.000000  31.000000
# mean   1998.258065  2005.258065   8.000000
# std       8.850491     9.273503   5.899152
# min    1980.000000  1989.000000   1.000000
# 25%    1993.000000  1996.000000   4.000000
# 50%    1998.000000  2007.000000   7.000000
# 75%    2004.500000  2016.000000  11.000000
# max    2013.000000  2016.000000  32.000000

# %% [markdown]
# <p>Платформы с наибольшими суммарными продажами:</p>
# <ul>
# <li><code>PS2    - 1233.56
# </code></li>
# <li><code>X360 - 961.24
# </code></li>
# <li><code>PS3    - 931.34
# </code></li>
# <li><code>Wii    - 891.18
# </code></li>
# <li><code>DS    - 802.78
# </code></li>
# <li><code>PS    - 727.58</code></li>
# </ul>
# <p>В основном жизнь платформы составляет 9-11 лет, пик приходится на 2-4 года.</p>
# <p>После выхода новой платформы в линейке, спрос на старую резко падает, начинает набирать оборот рост спроса на новую линейку.</p>
# <p>Новые платформы в линейках появляются каждые 6-7 лет</p>
# <p>В исследовании нас будут интересовать платформы, жизнь которых еще продолжается, а именно:</p>
# <ul>
# <li>XOne</li>
# <li>3DS</li>
# <li>X360</li>
# <li>WiiU</li>
# <li>Wii</li>
# <li>PSV</li>
# <li>PC</li>
# <li>PS4</li>
# <li>PS3</li>
# <p>Года будем брать, начиная с 2013, когда все интересующие нас платформы уже вышли</p>
# </ul>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Да, примерно столько они и живут. С выбором периода тоже согласна.
# </div>

# %%
act_p=lifetime['platform'].to_list()
act_p=act_p[:10]
act_p
# Out:
# ['XOne', '3DS', 'X360', 'WiiU', 'Wii', 'PSV', 'PC', 'PS4', 'PS3', 'PSP']

# %%
df_new = df[(df['platform'].isin(act_p))&(df['year_of_release']>=2013)]
df_new
# Out:
#                                 name platform  year_of_release         genre  \
# 16                Grand Theft Auto V      PS3             2013        Action
# 23                Grand Theft Auto V     X360             2013        Action
# 31         Call of Duty: Black Ops 3      PS4             2015       Shooter
# 33               Pokemon X/Pokemon Y      3DS             2013  Role-Playing
# 42                Grand Theft Auto V      PS4             2014        Action
# ...                              ...      ...              ...           ...
# 16703               Strawberry Nauts      PSV             2016     Adventure
# 16707               Aiyoku no Eustia      PSV             2014          Misc
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера  ⚠️</b>
#
# Понимаю, что тут можно просто скопировать список консолей и вставить, но если ты решишь поменять период, набор консолей тоже может поменяться, что повлечет за собой необходимость корректировать срез.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>Комментарий студента V1<a class="tocSkip"></h2>
# <div>Исправлено. Сначала не получалось, чтобы список платформ брать из списка. Долго думала )</div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Абсолютно верно! Можно и через query:
#
# </div>

# %%
# КОД РЕВЬЮЕРА 2

l = lifetime['platform'].to_list()[:10]

df.query('platform in @l and year_of_release>=2013')
# Out:
#                                 name platform  year_of_release         genre  \
# 16                Grand Theft Auto V      PS3             2013        Action
# 23                Grand Theft Auto V     X360             2013        Action
# 31         Call of Duty: Black Ops 3      PS4             2015       Shooter
# 33               Pokemon X/Pokemon Y      3DS             2013  Role-Playing
# 42                Grand Theft Auto V      PS4             2014        Action
# ...                              ...      ...              ...           ...
# 16703               Strawberry Nauts      PSV             2016     Adventure
# 16707               Aiyoku no Eustia      PSV             2014          Misc
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %% [markdown]
# ### Платформы, лидирующие по продажам, начиная с 2013 года

# %%
df_new.pivot_table(index=['platform'], values='total_sales', aggfunc='sum').sort_values('total_sales',ascending=False)
# Out:
#           total_sales
# platform
# PS4            314.14
# PS3            181.43
# XOne           159.32
# 3DS            143.25
# X360           136.80
# WiiU            64.63
# PC              39.43
# PSV             32.99
# Wii             13.66
# PSP              3.50

# %%
for i in act_p:
    pd.pivot_table(df_new.query('platform == @i'), index=['year_of_release'], values='total_sales', aggfunc='sum').plot(title = i, figsize=(10, 5), xlabel='Год выпуска', ylabel = 'Количество релизов').legend_ = None

# %% [markdown]
# <p>По продажам лидируют:</p>
# <table class="dataframe" border="1">
# <thead>
# <tr>
# <th>&nbsp;</th>
# </tr>
# <tr>
# <th>platform</th>
# <th>total_sales</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th>PS4</th>
# <td>314.14</td>
# </tr>
# <tr>
# <th>PS3</th>
# <td>181.43</td>
# </tr>
# <tr>
# <th>XOne</th>
# <td>159.32</td>
# </tr>
# <tr>
# <th>3DS</th>
# <td>143.25</td>
# </tr>
# <tr>
# <th>X360</th>
# <td>136.80</td>
# </tr>
# </tbody>
# </table>
# <p>Продажи на всех платформах падают.</p>
# <p>Так как данные за 2016 год неполные, то наиболее потенциально прибыльные платформы, судя по графикам - PS4 и XOne</p>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Очень красиво оформлена таблица в выводе 👍
# </div>

# %% [markdown]
# ### Глобальные продажи игр в разбивке по платформам

# %%
(df_new[['platform', 'total_sales']].boxplot(column='total_sales', by='platform', figsize=(15,10)))
plt.xlabel('Платформа')
plt.ylabel('Количество продаж')
plt.title('Глобальные продажи игр в разбивке по платформам')
# Out:
# Text(0.5, 1.0, 'Глобальные продажи игр в разбивке по платформам')

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера  ❌</b>
#
# График можно масштабировать, ограничив ось параметром **ylim**. Попробуешь?
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>Комментарий студента V1<a class="tocSkip"></h2>
# <div>Массштабируем график для лучшей визуализации</div>

# %%
(df_new[['platform', 'total_sales']].boxplot(column='total_sales', by='platform', figsize=(15,10))).set(ylim=(0, 5))
plt.xlabel('Платформа')
plt.ylabel('Количество продаж')
plt.title('Глобальные продажи игр в разбивке по платформам')
plt.show()

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Теперь ящики проще сравнивать.
# </div>

# %%
df_new['total_sales'].describe()
# Out:
# count    2225.000000
# mean        0.489506
# std         1.237281
# min         0.010000
# 25%         0.030000
# 50%         0.110000
# 75%         0.400000
# max        21.050000
# Name: total_sales, dtype: float64

# %%
df_new['total_sales'].describe
# Out:
# <bound method NDFrame.describe of 16       21.05
# 23       16.27
# 31       14.63
# 33       14.60
# 42       12.62
#          ...
# 16703     0.01
# 16707     0.01
# 16710     0.01
# 16712     0.01
# 16714     0.01
# Name: total_sales, Length: 2225, dtype: float64>

# %%
df_new.pivot_table(index='platform', values='total_sales', aggfunc=['count', 'sum', 'mean', 'median', 'std', 'min', 'max']).sort_values(('sum', 'total_sales'), ascending=False)
# Out:
#                count         sum        mean      median         std  \
#          total_sales total_sales total_sales total_sales total_sales
# platform
# PS4              392      314.14    0.801378       0.200    1.609456
# PS3              345      181.43    0.525884       0.150    1.451939
# XOne             247      159.32    0.645020       0.220    1.036139
# 3DS              303      143.25    0.472772       0.090    1.381347
# X360             186      136.80    0.735484       0.265    1.663275
# WiiU             115       64.63    0.562000       0.200    1.038778
# PC               189       39.43    0.208624       0.080    0.352304
# PSV              358       32.99    0.092151       0.040    0.153816
# Wii               23       13.66    0.593913       0.180    0.915432
# PSP               67        3.50    0.052239       0.020    0.059768
#
#                  min         max
#          total_sales total_sales
# platform
# PS4             0.01       14.63
# ...

# %%
df_new['total_sales'].quantile(.99)
# Out:
# 5.4507999999999805

# %%
df_new.query('total_sales > 5.45').sort_values(by='total_sales', ascending=False)
# Out:
#                                           name platform  year_of_release  \
# 16                          Grand Theft Auto V      PS3             2013
# 23                          Grand Theft Auto V     X360             2013
# 31                   Call of Duty: Black Ops 3      PS4             2015
# 33                         Pokemon X/Pokemon Y      3DS             2013
# 42                          Grand Theft Auto V      PS4             2014
# 47   Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS             2014
# 60                        Call of Duty: Ghosts     X360             2013
# 69                        Call of Duty: Ghosts      PS3             2013
# 72                                   Minecraft     X360             2013
# 77                                     FIFA 16      PS4             2015
# 87                Star Wars Battlefront (2015)      PS4             2015
# 92              Call of Duty: Advanced Warfare      PS4             2014
# ...

# %% [markdown]
# По количеству и сумме продаж лидируют игры на платформе PS4, на графике можно видеть большие выбросы - это бестселлеры, игры, продающиеся чаще всего. К примеру, на платформе 3DS большую выручку приносят бестселлеры(маленький ящик и большие выбросы). Для платформы XOne характерен ящик большего размера и меньшее число выбросов. У платформы PS3 есть супер выброс - это GTA5. Выше можно увидеть таблицу с самыми продаваемыми играми.
#
# Медианные продажи у большинства платформ в районе 200000, но среднее стремится к миллиону, что в очередной раз доказывает большие выбросы.
#
# Наименьшие выбросы заметны у PSP, PSV и PC.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера  ✔️</h2>
#
# Абсолютно верно.
# </div>

# %% [markdown]
# ### Влияние отзывов на продажи

# %%
PS4_score = df_new.query('platform == "PS4"')
PS4_score = PS4_score.loc[:,['total_sales', 'critic_score', 'user_score']]

# %%
PS4_score
# Out:
#        total_sales  critic_score  user_score
# 31           14.63           NaN         NaN
# 42           12.62          97.0         8.3
# 77            8.58          82.0         4.3
# 87            7.98           NaN         NaN
# 92            7.66          83.0         5.7
# ...            ...           ...         ...
# 16500         0.01          69.0         7.5
# 16503         0.01           NaN         NaN
# 16526         0.01          61.0         7.9
# 16530         0.01          51.0         5.5
# 16585         0.01           NaN         NaN
#
# [392 rows x 3 columns]

# %%
PS4_score.corr()
# Out:
#               total_sales  critic_score  user_score
# total_sales      1.000000      0.406568   -0.031957
# critic_score     0.406568      1.000000    0.557654
# user_score      -0.031957      0.557654    1.000000

# %%
pd.plotting.scatter_matrix(PS4_score, figsize=(15, 10))
# Out:
# array([[<AxesSubplot:xlabel='total_sales', ylabel='total_sales'>,
#         <AxesSubplot:xlabel='critic_score', ylabel='total_sales'>,
#         <AxesSubplot:xlabel='user_score', ylabel='total_sales'>],
#        [<AxesSubplot:xlabel='total_sales', ylabel='critic_score'>,
#         <AxesSubplot:xlabel='critic_score', ylabel='critic_score'>,
#         <AxesSubplot:xlabel='user_score', ylabel='critic_score'>],
#        [<AxesSubplot:xlabel='total_sales', ylabel='user_score'>,
#         <AxesSubplot:xlabel='critic_score', ylabel='user_score'>,
#         <AxesSubplot:xlabel='user_score', ylabel='user_score'>]],
#       dtype=object)

# %% [markdown]
# Линейная корреляция наблюдается между рейтингом критиков и пользователей. Корреляция между продажами и рейтингом критиков не линейная, слабая.
#
# На продажи PS4 больше влияет рейтинг критиков, рейтинг пользователей не влияет (нулевой коэффициент). На мнение пользователей также сильно влияет мнение критиков. А критики - это по большей части реклама, так что реклама - двигатель торговли.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера  ⚠️</b>
#
# 0.4 это скорее слабая связь.
#
#
# У пользователей коэфф-т нулевой, поэтому минус там не играет роли.
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# 👍
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>Комментарий студента V1<a class="tocSkip"></h2>
# <div>Исправлено</div>

# %%
PS3_score = df_new.query('platform == "PS3"')
PS3_score = PS3_score.loc[:,['total_sales', 'critic_score', 'user_score']]
PS3_score.corr()
# Out:
#               total_sales  critic_score  user_score
# total_sales      1.000000      0.334285    0.002394
# critic_score     0.334285      1.000000    0.599920
# user_score       0.002394      0.599920    1.000000

# %%
pd.plotting.scatter_matrix(PS3_score, figsize=(15, 10))
# Out:
# array([[<AxesSubplot:xlabel='total_sales', ylabel='total_sales'>,
#         <AxesSubplot:xlabel='critic_score', ylabel='total_sales'>,
#         <AxesSubplot:xlabel='user_score', ylabel='total_sales'>],
#        [<AxesSubplot:xlabel='total_sales', ylabel='critic_score'>,
#         <AxesSubplot:xlabel='critic_score', ylabel='critic_score'>,
#         <AxesSubplot:xlabel='user_score', ylabel='critic_score'>],
#        [<AxesSubplot:xlabel='total_sales', ylabel='user_score'>,
#         <AxesSubplot:xlabel='critic_score', ylabel='user_score'>,
#         <AxesSubplot:xlabel='user_score', ylabel='user_score'>]],
#       dtype=object)

# %%
X360_score = df_new.query('platform == "X360"')
X360_score = X360_score.loc[:,['total_sales', 'critic_score', 'user_score']]
X360_score.corr()
# Out:
#               total_sales  critic_score  user_score
# total_sales      1.000000      0.350345   -0.011742
# critic_score     0.350345      1.000000    0.520946
# user_score      -0.011742      0.520946    1.000000

# %%
pd.plotting.scatter_matrix(X360_score, figsize=(15, 10))
# Out:
# array([[<AxesSubplot:xlabel='total_sales', ylabel='total_sales'>,
#         <AxesSubplot:xlabel='critic_score', ylabel='total_sales'>,
#         <AxesSubplot:xlabel='user_score', ylabel='total_sales'>],
#        [<AxesSubplot:xlabel='total_sales', ylabel='critic_score'>,
#         <AxesSubplot:xlabel='critic_score', ylabel='critic_score'>,
#         <AxesSubplot:xlabel='user_score', ylabel='critic_score'>],
#        [<AxesSubplot:xlabel='total_sales', ylabel='user_score'>,
#         <AxesSubplot:xlabel='critic_score', ylabel='user_score'>,
#         <AxesSubplot:xlabel='user_score', ylabel='user_score'>]],
#       dtype=object)

# %%
score = df_new.loc[:,['total_sales', 'critic_score', 'user_score']]

# %%
score.corr()
# Out:
#               total_sales  critic_score  user_score
# total_sales      1.000000      0.313700   -0.002812
# critic_score     0.313700      1.000000    0.502221
# user_score      -0.002812      0.502221    1.000000

# %% [markdown]
# На других платформах ситуация аналогичная. В общем плане также аналогичная с PS4 ситуация прослеживается.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера  ✔️</h2>
#
# Да, все то же самое. </div>

# %% [markdown]
# ###  Распределение игр по жанрам

# %%
df_new.pivot_table( index='genre', values='total_sales', aggfunc=['sum', 'mean', 'median']).sort_values(('mean', 'total_sales'), ascending=False)
# Out:
#                      sum        mean      median
#              total_sales total_sales total_sales
# genre
# Shooter           232.98    1.245882       0.450
# Sports            150.62    0.707136       0.240
# Platform           41.94    0.582500       0.225
# Role-Playing      145.89    0.499623       0.125
# Racing             39.89    0.469294       0.120
# Fighting           35.31    0.441375       0.125
# Action            321.37    0.420641       0.110
# Misc               62.74    0.407403       0.105
# Simulation         21.55    0.353279       0.100
# Puzzle              3.17    0.186471       0.060
# Strategy           10.08    0.180000       0.080
# Adventure          23.61    0.096762       0.030

# %%
(df_new[['total_sales', 'genre']].boxplot(column='total_sales', by='genre', figsize=(10,8))).set(ylim=(0, 5))
plt.xlabel('Жанр')
plt.ylabel('Количество проданных копий')
plt.title('Диаграммы размаха по продажам в разных жанрах')
plt.show()

# %% [markdown]
# Самые продаваемые жанры: action, shooter, sports и role-playing. С большим отрывом от них идут жанры Misc, Platform, Racing, Fighting, Adventure, Simulation, Strategy. Наименее популярный жанр - Puzzle.
#
# Экшены лидеры по количеству проданных копий, но по средним и медианным продажам стоят всего лишь на 7 месте. Шутеры в лидерах и по средним продажам и по количеству бестселлеров.
#
#
# *Больше ничего не могу сказать про жанры, компьютерные игры - не мой конек :(*

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера  ✔️</h2>
#
# > Больше ничего не могу сказать про жанры, компьютерные игры - не мой конек
#
#
# Прекрасно понимаю :) </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера ❌ </b>
#
# Вообще, про прибыльность мы тут говорить не можем, ведь речь о млн копий, да и нет у нас информации о себестоимости. Тут имеется в виду скорее успешность в продажах. Хорошо. А может ли быть такая ситуация, что экшн делает продажи только за счет большего количества игр и большого количества бестселлеров? Быть может, другие жанры имеют больше продаж в расчете на единицу игры. Сделай то же самое, но с медианными/средними  продажами.
# </div>
# <div class="alert alert-success " style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2  ✔️</h2>
#
# Теперь экшн не такой популярный :) Это нам говорит о том, что у этого жанра очень много игр, которые мало покупают. А вот у шутера гораздо больше игр покупают в большом количестве.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>Комментарий студента V1<a class="tocSkip"></h2>
# <div>Исправлено</div>

# %% [markdown]
# ## Портрет пользователя каждого региона

# %% [markdown]
# ### North America

# %%
na_platf = df_new.pivot_table(index=['platform'], values=['na_sales', 'total_sales'], aggfunc='sum').sort_values(by='na_sales', ascending=False).head(5)
na_platf['percent'] = round(na_platf['na_sales'] / na_platf['total_sales']*100, 2)
na_platf
# Out:
#           na_sales  total_sales  percent
# platform
# PS4         108.74       314.14    34.62
# XOne         93.12       159.32    58.45
# X360         81.66       136.80    59.69
# PS3          63.50       181.43    35.00
# 3DS          38.20       143.25    26.67

# %%
na_genre = df_new.pivot_table(index=['genre'], values='na_sales', aggfunc='sum').sort_values(by='na_sales', ascending=False).head(5)
na_genre
# Out:
#               na_sales
# genre
# Action          125.83
# Shooter         109.74
# Sports           65.27
# Role-Playing     46.40
# Misc             27.46

# %% [markdown]
# Заменим неизвестный рейтинг на no_rating для лучшего исследования рейтингов

# %%
df_new.loc[df_new['rating'].isnull(),'rating'] = 'no_rating'
df_new.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       1234
# user_score         1034
# rating                0
# total_sales           0
# dtype: int64

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера  ✔️</h2>
#
# Это предупреждение просто напоминает о том, что мы работаем с ранее созданной копией какого-то датафрейма. Кстати, предупреждения можно отключать:
# </div>
#
# ```python
#
# import warnings
# warnings.filterwarnings('ignore')
# ```

# %%
df_new.pivot_table(index='rating', values='na_sales', aggfunc='mean').sort_values(by='na_sales').plot(kind='bar', figsize=(10, 5))
plt.xlabel('Рейтинг')
plt.ylabel('Количество проданных игр')
plt.title('Продажи в зависимости от рейтинга в Северной Америке')
# Out:
# Text(0.5, 1.0, 'Продажи в зависимости от рейтинга в Северной Америке')

# %% [markdown]
# В Северной Америке предпочитают игры на PS4, далее, с большим отрывом идет XOne. В основном играют в экшены и шутеры. Игры любят для взрослых.
#
# Более 50% проданных игр в Северной Америке - игры на платформах XOne и X360.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера  ⚠️</b>
#
# Напомню, что мы ничего не знаем о выручке.
# </div>
# <div class="alert alert-success " style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2  ✔️</h2>
#
# Хорошо.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>Комментарий студента V1<a class="tocSkip"></h2>
# <div>Исправлено</div>

# %% [markdown]
# ### Europe

# %%
eu_platf = df_new.pivot_table(index=['platform'], values=['eu_sales', 'total_sales'], aggfunc='sum').sort_values(by='eu_sales', ascending=False).head(5)
eu_platf['percent'] = round(eu_platf['eu_sales'] / eu_platf['total_sales']*100, 2)
eu_platf
# Out:
#           eu_sales  total_sales  percent
# platform
# PS4         141.09       314.14    44.91
# PS3          67.81       181.43    37.38
# XOne         51.59       159.32    32.38
# X360         42.52       136.80    31.08
# 3DS          30.96       143.25    21.61

# %%
df_new.pivot_table(index=['genre'], values='eu_sales', aggfunc='sum').sort_values(by='eu_sales', ascending=False).head(5)
# Out:
#               eu_sales
# genre
# Action          117.89
# Shooter          87.86
# Sports           60.49
# Role-Playing     36.97
# Racing           20.19

# %%
df_new.pivot_table(index='rating', values='eu_sales', aggfunc='mean').sort_values(by='eu_sales').plot(kind='bar', figsize=(10, 5))
plt.xlabel('Рейтинг')
plt.ylabel('Количество проданных игр')
plt.title('Продажи в зависимости от рейтинга в Европе')
# Out:
# Text(0.5, 1.0, 'Продажи в зависимости от рейтинга в Европе')

# %% [markdown]
# В Европе ситуация с жанрами, как и в Северной Америке, любят также игры с рейтингом М, приставки предпочитают PS4 и PS3, игры на платформе PS4 в Европе делают почти половину выручки от общего числа продаж.

# %% [markdown]
# ### Japan

# %%
jp_platf = df_new.pivot_table(index=['platform'], values=['jp_sales', 'total_sales'], aggfunc='sum').sort_values(by='jp_sales', ascending=False).head(5)
jp_platf['percent'] = round(jp_platf['jp_sales'] / jp_platf['total_sales']*100, 2)
jp_platf
# Out:
#           jp_sales  total_sales  percent
# platform
# 3DS          67.81       143.25    47.34
# PS3          23.35       181.43    12.87
# PSV          18.59        32.99    56.35
# PS4          15.96       314.14     5.08
# WiiU         10.88        64.63    16.83

# %%
df_new.pivot_table(index=['genre'], values='jp_sales', aggfunc='sum').sort_values(by='jp_sales', ascending=False).head(5)
# Out:
#               jp_sales
# genre
# Role-Playing     51.04
# Action           40.49
# Misc              9.20
# Fighting          7.65
# Shooter           6.61

# %%
df_new.pivot_table(index='rating', values='jp_sales', aggfunc='mean').sort_values(by='jp_sales').plot(kind='bar', figsize=(10, 5))
plt.xlabel('Рейтинг')
plt.ylabel('Количество проданных игр')
plt.title('Продажи в зависимости от рейтинга в Японии')
# Out:
# Text(0.5, 1.0, 'Продажи в зависимости от рейтинга в Японии')

# %% [markdown]
# А вот в Японии все очень интересно.Японцы предпочитают ролевые игры и портативные притставки. И, похоже, что у Японцев имеется свой рейтинг. Наверное, игры, идущие на экспорт, либо импортные игры имеют рейтинг ESRB, а игры для внутреннего рынка имеют свой рейтинг CERO. Видимо, японцы предпочитают японские игры и японские приставки )

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера  ✔️</h2>
#
# Да, Япония отличилась по всем параметрам. Согласна с твоими выводами.
#
# </div>

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# ### Ho - Средние пользовательские рейтинги платформ Xbox One и PC одинаковые

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера  ⚠️</b>
#
# Загрузку лучше делать в начале проекта, тогда читателю будет сразу понятно, какие модули потребуются для запуска проекта.
#
# </div>
# <div class="alert alert-success " style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2  ✔️</h2>
#
# Отлично.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>Комментарий студента V1<a class="tocSkip"></h2>
# <div>Исправлено</div>

# %%
Xbox_One = df_new[(df_new['platform'] == 'XOne') & (df_new['user_score'].notna())]['user_score']
PC = df_new[(df_new['platform'] == 'PC') & (df_new['user_score'].notna())]['user_score']

alpha = 0.05
results = st.ttest_ind(Xbox_One, PC)

print('p-value:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-value: 0.14012658403611647
# Не получилось отвергнуть нулевую гипотезу

# %%
df_new.query('platform in ["XOne", "PC"]').pivot_table(index='platform', values='user_score', aggfunc='mean')
# Out:
#           user_score
# platform
# PC          6.269677
# XOne        6.521429

# %% [markdown]
# Нулевая гипотеза: Средние пользовательские рейтинги платформ Xbox One и PC одинаковые. Альтернативная гипотеза: Средние пользовательские рейтинги платформ Xbox One и PC не одинаковые (разные).
#
# Для проверки гипотез применили критерий Стьюдента и уровень значимости 5%, так как сравнивались средние значения.
#
# p-value: 0.14012658403611647
#
# Не получилось отвергнуть нулевую гипотезу. Рейтинги одинаковые.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера  ✔️</h2>
#
# Верно.
# </div>

# %% [markdown]
# ### Ho - Средние пользовательские рейтинги жанров Action и Sports разные.

# %%
action = df_new[(df_new['genre'] == 'Action') & (df_new['user_score'].notna())]['user_score'] 
sports = df_new[(df_new['genre'] == 'Sports') & (df_new['user_score'].notna())]['user_score']
alpha = 0.05
results = st.ttest_ind(action, sports)

print('p-value:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-value: 7.102366533466476e-28
# Отвергаем нулевую гипотезу

# %%
df_new.query('genre in ["Action", "Sports"]').pivot_table(index='genre', values='user_score', aggfunc='mean')
# Out:
#         user_score
# genre
# Action    6.842784
# Sports    5.238125

# %% [markdown]
# Нулевая гипотеза: Средние пользовательские рейтинги жанров Action и Sports одинаковые. Альтернативная гипотеза: Средние пользовательские рейтинги жанров Action и Sports разные.
#
# Для проверки гипотез применили критерий Стьюдента и уровень значимости 5%, так как сравнивались средние значения.
#
# p-value: 7.102366533466476e-28
#
# Отвергаем нулевую гипотезу.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера ⚠️</b>
#
# То, что мы отвергаем одну гипотезу, еще не значит, что верна другая.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>Комментарий студента V1<a class="tocSkip"></h2>
# <div>Исправлено</div>

# %% [markdown]
# ## Вывод

# %% [markdown]
# <p>Объект исследования - исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы из открытых источников.</p>
# <p>В процессе предобработки данных были приведены названия столбцов к нижнему регистру, удалены пропуски с названием игр (2 строки) и с пропущенным годом релиза (менее 2% от всего объема данных), пропуски в рейтенге заменены на 'no_rating'.</p>
# <p>Общий вывод из ИА:</p>
# <p>Начиная с 2010 года количество релизов новых игр идет на спад, наибольшее количество игр было выпущено в 2008 - 2009 годах.</p>
# <p>За все время наболюдений наиболее продаваемые платформы были:</p>
# <pre><code>PS2    - 1233.56
# X360 - 961.24
# PS3    - 931.34
# Wii    - 891.18
# DS    - 802.78
# PS    - 727.58<br /><br /></code></pre>
# <p>В основном жизнь платформы составляет 9-11 лет, пик приходится на 2-4 года.<br />После выхода новой платформы в линейке, спрос на старую резко падает, начинает набирать оборот рост спроса на новую линейку.<br />Новые платформы в линейках появляются каждые 6-7 лет</p>
# <p>Для дальнейшего исследования были оставлены платформы, жизнь которых еще продолжается, а именно:</p>
# <ul>
# <ul>
# <li>XOne</li>
# <li>3DS</li>
# <li>X360</li>
# <li>WiiU</li>
# <li>Wii</li>
# <li>PSV</li>
# <li>PC</li>
# <li>PS4</li>
# <li>PS3</li>
# </ul>
# </ul>
# <p>Года взяты, начиная с 2013, когда все интересующие нас платформы уже вышли.</p>
# <p>Описав портреты пользователей по каждому региону, выяснилось, что пользователи из Европы и Северной Америки практически одинаковы:</p>
# <p>В Северной Америке предпочитают игры на PS4, далее, с большим отрывом идет XOne. В основном играют в экшены и шутеры. Игры любят для взрослых. Более 50% проданных игр в Северной Америке - игры на платформах XOne и X360.</p>
# <p>В Европе ситуация с жанрами, как и в Северной Америке, любят также игры с рейтингом М, приставки предпочитают PS4 и PS3, игры на платформе PS4 в Европе делают почти половину выручки от общего числа продаж.</p>
# <p>Японцы предпочитают ролевые игры и экшены, портативные притставки японского производителя 3 DS и с большим отрывом идет PS3. И, похоже, что у Японцев имеется свой рейтинг. Наверное, игры, идущие на экспорт, либо импортные игры имеют рейтинг ESRB, а игры для внутреннего рынка имеют свой рейтинг CERO</p>
# <p>Были проверены 2 гипотезы и выяснилось, что:</p>
# <p>Средние пользовательские рейтинги платформ Xbox One и PC одинаковые</p>
# <p>Средние пользовательские рейтинги жанров Action и Sports разные</p>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера ❌</b>
#
#
# Вывод хороший. Будет здорово, если добавишь  конкретику по регионам:  2-3 консоли, 2-3 жанра и рейтинги. Также не забудь обновить вывод после внесения изменений.
#
# </div>
# <div class="alert alert-success " style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2  ✔️</h2>
#
# Замечательная работа получилась :)
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2>Комментарий студента V1<a class="tocSkip"></h2>
# <div>Исправлено</div>
